# %% [markdown]
# ## Data cleaning
# * dropna
# * fillna
# * Forward Fill
# * Backward Fil
# * Interpolate
# * Mean
# * Median
# * Mode

# %%
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Computer'

# %%
os.listdir(os.getcwd())
# Out:
# ['.conda',
#  '.condarc',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '.vscode',
#  '09.10.2022.ipynb',
#  '2022_Python_projects.ipynb',
#  '31.08.2022.ipynb',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'covid.py',
#  'covid19.csv',
#  'covid191.csv',
#  'credits.csv',
#  'data science.ipynb',
#  'data.csv',
#  'data_science_python_sample_code.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'java',
#  'Jedi',
#  'Links',
#  'Local Settings',
#  'Movie Recommendation.ipynb',
#  'Movie Recommendation.py',
#  'movies.csv',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
# ...

# %%
df = pd.read_csv("/Users/Computer/Documents/sql project/Student_report.csv")

# %%
df
# Out:
#    S.No                Name                           College  C-Marks   Hsc  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      NaN  56.0
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0   NaN
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6     7            NIKESH.P  Government art & science college      NaN  78.0
# 7     8                 NaN                               NaN      NaN   NaN
# 8     9             RAMAN.S                     Amman collage     86.0  46.0
# 9    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#    Sslc  Cureent Arreares
# 0   NaN               1.0
# 1  67.0               6.0
# 2  67.0               NaN
# ...

# %%
df.describe()
# Out:
#            S.No    C-Marks        Hsc       Sslc  Cureent Arreares
# count  10.00000   7.000000   8.000000   6.000000          7.000000
# mean    5.50000  58.000000  63.625000  70.500000          1.571429
# std     3.02765  26.789301  16.604109   9.396808          2.070197
# min     1.00000  23.000000  34.000000  55.000000          0.000000
# 25%     3.25000  37.000000  53.500000  67.000000          0.500000
# 50%     5.50000  56.000000  71.000000  71.500000          1.000000
# 75%     7.75000  82.000000  75.750000  77.500000          1.500000
# max    10.00000  89.000000  78.000000  80.000000          6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S.No              10 non-null     int64
#  1   Name              9 non-null      object
#  2   College           9 non-null      object
#  3   C-Marks           7 non-null      float64
#  4   Hsc               8 non-null      float64
#  5   Sslc              6 non-null      float64
#  6   Cureent Arreares  7 non-null      float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 688.0+ bytes

# %%
df.isnull().sum()
# Out:
# S.No                0
# Name                1
# College             1
# C-Marks             3
# Hsc                 2
# Sslc                4
# Cureent Arreares    3
# dtype: int64

# %%
df.dropna(how="any")
# Out:
#    S.No           Name        College  C-Marks   Hsc  Sslc  Cureent Arreares
# 1     2  MADHAN BABU.B  Amman collage     23.0  75.0  67.0               6.0
# 8     9        RAMAN.S  Amman collage     86.0  46.0  76.0               1.0
# 9    10      SUNDHAR.S    CNC college     56.0  75.0  55.0               0.0

# %%
df.dropna(how="all")
# Out:
#    S.No                Name                           College  C-Marks   Hsc  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      NaN  56.0
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0   NaN
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6     7            NIKESH.P  Government art & science college      NaN  78.0
# 7     8                 NaN                               NaN      NaN   NaN
# 8     9             RAMAN.S                     Amman collage     86.0  46.0
# 9    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#    Sslc  Cureent Arreares
# 0   NaN               1.0
# 1  67.0               6.0
# 2  67.0               NaN
# ...

# %%
df.dropna(subset=['C-Marks'],how = 'any')
# Out:
#    S.No                Name                           College  C-Marks   Hsc  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0   NaN
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 8     9             RAMAN.S                     Amman collage     86.0  46.0
# 9    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#    Sslc  Cureent Arreares
# 0   NaN               1.0
# 1  67.0               6.0
# 3   NaN               2.0
# 4  80.0               0.0
# 5  78.0               NaN
# 8  76.0               1.0
# 9  55.0               0.0

# %%
df.dropna().shape
# Out:
# (3, 7)

# %%
df.shape
# Out:
# (10, 7)

# %% [markdown]
# # Fillna Function using to fill null values dataset.

# %%
df
# Out:
#    S.No                Name                           College  C-Marks  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      NaN
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0
# 6     7            NIKESH.P  Government art & science college      NaN
# 7     8                 NaN                               NaN      NaN
# 8     9             RAMAN.S                     Amman collage     86.0
# 9    10           SUNDHAR.S                       CNC college     56.0
#
#       Hsc  Sslc  Cureent Arreares
# 0  78.000   NaN               1.0
# 1  75.000  67.0               6.0
# 2  56.000  67.0               NaN
# 3  34.000   NaN               2.0
# ...

# %%
df.fillna(0)
# Out:
#    S.No                Name                           College  C-Marks   Hsc  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      0.0  56.0
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0   0.0
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6     7            NIKESH.P  Government art & science college      0.0  78.0
# 7     8                   0                                 0      0.0   0.0
# 8     9             RAMAN.S                     Amman collage     86.0  46.0
# 9    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#    Sslc  Cureent Arreares
# 0   0.0               1.0
# 1  67.0               6.0
# 2  67.0               0.0
# ...

# %%
df.fillna(method = 'bfill')
# Out:
#    S.No                Name                           College  C-Marks   Hsc  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2     3     MAHENDRAKUMAR.R                       CNC college     42.0  56.0
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0  67.0
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6     7            NIKESH.P  Government art & science college     86.0  78.0
# 7     8             RAMAN.S                     Amman collage     86.0  46.0
# 8     9             RAMAN.S                     Amman collage     86.0  46.0
# 9    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#    Sslc  Cureent Arreares
# 0  67.0               1.0
# 1  67.0               6.0
# 2  67.0               2.0
# ...

# %%
df.fillna(method = 'ffill')
# Out:
#    S.No                Name                           College  C-Marks   Hsc  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2     3     MAHENDRAKUMAR.R                       CNC college     23.0  56.0
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0  34.0
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6     7            NIKESH.P  Government art & science college     78.0  78.0
# 7     8            NIKESH.P  Government art & science college     78.0  78.0
# 8     9             RAMAN.S                     Amman collage     86.0  46.0
# 9    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#    Sslc  Cureent Arreares
# 0   NaN               1.0
# 1  67.0               6.0
# 2  67.0               6.0
# ...

# %%
df.interpolate()
# Out:
#    S.No                Name                           College    C-Marks  \
# 0     1        LOGANATHAN.M                Sri vasavi college  32.000000
# 1     2       MADHAN BABU.B                     Amman collage  23.000000
# 2     3     MAHENDRAKUMAR.R                       CNC college  32.500000
# 3     4       MAHESHKUMAR.P  Government art & science college  42.000000
# 4     5        MANIKANDAN.P                     Amman collage  89.000000
# 5     6  MOHANAMANIKANDAN.K                       CNC college  78.000000
# 6     7            NIKESH.P  Government art & science college  80.666667
# 7     8                 NaN                               NaN  83.333333
# 8     9             RAMAN.S                     Amman collage  86.000000
# 9    10           SUNDHAR.S                       CNC college  56.000000
#
#     Hsc       Sslc  Cureent Arreares
# 0  78.0        NaN               1.0
# 1  75.0  67.000000               6.0
# 2  56.0  67.000000               4.0
# ...

# %% [markdown]
# # Mean, Median, Mode

# %%
df
# Out:
#    S.No                Name                           College  C-Marks   Hsc  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      NaN  56.0
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0   NaN
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6     7            NIKESH.P  Government art & science college      NaN  78.0
# 7     8                 NaN                               NaN      NaN   NaN
# 8     9             RAMAN.S                     Amman collage     86.0  46.0
# 9    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#    Sslc  Cureent Arreares
# 0   NaN               1.0
# 1  67.0               6.0
# 2  67.0               NaN
# ...

# %%
mean = df.Hsc.mean()
mean
# Out:
# 63.625

# %%
df.Hsc.fillna(mean)
df
# Out:
#    S.No                Name                           College  C-Marks  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      NaN
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0
# 6     7            NIKESH.P  Government art & science college      NaN
# 7     8                 NaN                               NaN      NaN
# 8     9             RAMAN.S                     Amman collage     86.0
# 9    10           SUNDHAR.S                       CNC college     56.0
#
#       Hsc  Sslc  Cureent Arreares
# 0  78.000   NaN               1.0
# 1  75.000  67.0               6.0
# 2  56.000  67.0               NaN
# 3  34.000   NaN               2.0
# ...

# %%
df.Hsc.fillna(median)
df
# Out:
#    S.No                Name                           College  C-Marks  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      NaN
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0
# 6     7            NIKESH.P  Government art & science college      NaN
# 7     8                 NaN                               NaN      NaN
# 8     9             RAMAN.S                     Amman collage     86.0
# 9    10           SUNDHAR.S                       CNC college     56.0
#
#       Hsc  Sslc  Cureent Arreares
# 0  78.000   NaN               1.0
# 1  75.000  67.0               6.0
# 2  56.000  67.0               NaN
# 3  34.000   NaN               2.0
# ...

# %%
median = df.Hsc.median()
median
# Out:
# 65.3125

# %%
mode = df.Hsc.mode()
mode
# Out:
# 0    63.625
# 1    75.000
# 2    78.000
# Name: Hsc, dtype: float64

# %%
mode_value = 75.000

# %%
df.Hsc.fillna(mode_value,inplace = True)
df
# Out:
#    S.No                Name                           College  C-Marks  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      NaN
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0
# 6     7            NIKESH.P  Government art & science college      NaN
# 7     8                 NaN                               NaN      NaN
# 8     9             RAMAN.S                     Amman collage     86.0
# 9    10           SUNDHAR.S                       CNC college     56.0
#
#       Hsc  Sslc  Cureent Arreares
# 0  78.000   NaN               1.0
# 1  75.000  67.0               6.0
# 2  56.000  67.0               NaN
# 3  34.000   NaN               2.0
# ...

# %% [markdown]
# # Remove Duplicates, cleaning wrong Format, Cleaning Wrong Date.

# %%
df
# Out:
#     S.No                Name                           College  C-Marks   Hsc  \
# 0      1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1      2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2      3     MAHENDRAKUMAR.R                       CNC college      NaN  56.0
# 3      4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4      5        MANIKANDAN.P                     Amman collage     89.0   NaN
# 5      6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6      7            NIKESH.P  Government art & science college      NaN  78.0
# 7      8                 NaN                               NaN      NaN   NaN
# 8      9             RAMAN.S                     Amman collage     86.0  46.0
# 9     10           SUNDHAR.S                       CNC college     56.0  75.0
# 10    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#     Sslc  Cureent Arreares
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# dtype: bool

# %%
dupllicate_vau1 = df.drop_duplicates(inplace=True)

# %%
dupllicate_vau1

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#    S.No                Name                           College  C-Marks   Hsc  \
# 0     1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1     2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2     3     MAHENDRAKUMAR.R                       CNC college      NaN  56.0
# 3     4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4     5        MANIKANDAN.P                     Amman collage     89.0   NaN
# 5     6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6     7            NIKESH.P  Government art & science college      NaN  78.0
# 7     8                 NaN                               NaN      NaN   NaN
# 8     9             RAMAN.S                     Amman collage     86.0  46.0
# 9    10           SUNDHAR.S                       CNC college     56.0  75.0
#
#    Sslc  Cureent Arreares
# 0   NaN               1.0
# 1  67.0               6.0
# 2  67.0               NaN
# ...

# %%
df = pd.read_csv("/Users/Computer/Documents/sql project/Student_report.csv")

# %%
df
# Out:
#     S.No                Name                           College  C-Marks   Hsc  \
# 0      1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1      2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2      3     MAHENDRAKUMAR.R                       CNC college      NaN  56.0
# 3      4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4      5        MANIKANDAN.P                     Amman collage     89.0   NaN
# 5      6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6      7            NIKESH.P  Government art & science college      NaN  78.0
# 7      8                 NaN                               NaN      NaN   NaN
# 8      9             RAMAN.S                     Amman collage     86.0  46.0
# 9     10           SUNDHAR.S                       CNC college     56.0  75.0
# 10    10           SUNDHAR.S                       CNC college     56.0  75.0
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#     S.No                Name                           College  C-Marks   Hsc  \
# 0      1        LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 1      2       MADHAN BABU.B                     Amman collage     23.0  75.0
# 2      3     MAHENDRAKUMAR.R                       CNC college      NaN  56.0
# 3      4       MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 4      5        MANIKANDAN.P                     Amman collage     89.0   NaN
# 5      6  MOHANAMANIKANDAN.K                       CNC college     78.0  67.0
# 6      7            NIKESH.P  Government art & science college      NaN  78.0
# 7      8                 NaN                               NaN      NaN   NaN
# 8      9             RAMAN.S                     Amman collage     86.0  46.0
# 9     10           SUNDHAR.S                       CNC college     56.0  75.0
# 10    10           SUNDHAR.S                       CNC college     56.0  75.0
#
# ...

# %%
for x in df.index:
    if df.loc[x, "Sslc"] > 75:
        df.drop(x, inplace = True)

# %%
df
# Out:
#     S.No           Name                           College  C-Marks   Hsc  \
# 0      1   LOGANATHAN.M                Sri vasavi college     32.0  78.0
# 3      4  MAHESHKUMAR.P  Government art & science college     42.0  34.0
# 6      7       NIKESH.P  Government art & science college      NaN  78.0
# 7      8            NaN                               NaN      NaN   NaN
# 9     10      SUNDHAR.S                       CNC college     56.0  75.0
# 10    10      SUNDHAR.S                       CNC college     56.0  75.0
#
#     Sslc  Cureent Arreares       Date
# 0    NaN               1.0 2017-05-23
# 3    NaN               2.0        NaT
# 6    NaN               1.0 2017-05-23
# 7    NaN               NaN 2016-02-20
# 9   55.0               0.0 2018-09-22
# 10  55.0               0.0        NaT
